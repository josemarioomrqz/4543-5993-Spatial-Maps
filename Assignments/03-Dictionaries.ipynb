# %% [markdown]
# # 📘 03 - Python Dictionaries
#
# Dictionaries store key-value pairs for fast lookups.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access dictionary items
# - Use dictionary methods like `.get()` and `.items()`

# %%
# 📚 Create a Dictionary
student = {'name': 'Alex', 'age': 21, 'major': 'CS'}
print(student)
# Out:
# {'name': 'Alex', 'age': 21, 'major': 'CS'}

# %%
# 🔍 Access Values
print(student['name'])
print(student.get('gpa', 'N/A'))
# Out:
# Alex
# N/A

# %%
# 🔁 Loop Over Dictionary
for key, value in student.items():
    print(key, '->', value)
# Out:
# name -> Alex
# age -> 21
# major -> CS

# %% [markdown]
# ## ✏️ Your Turn
# Create a dictionary to store information about your favorite book.

# %% [markdown]
# ## Jose Marquez
# ## Assignment 03 Part 2 - Dictionaries

# %%
# This program displays a dictionary of my favorite book. 

favorite_book = {'Title': 'Percy Jackson and the Olympians: The Lightning Thief', 'Author': 'Rick Riordan', 'Year': 2005}
print(favorite_book.get('Title'), 'by', favorite_book.get('Author'), 'published in', favorite_book.get('Year'))
# Out:
# Percy Jackson and the Olympians: The Lightning Thief by Rick Riordan published in 2005
