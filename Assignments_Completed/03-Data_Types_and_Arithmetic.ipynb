# %% [markdown]
# # 📘 03 - Data Types and Arithmetic
#
# Explore Python basics like variables, data types, and arithmetic operations.

# %% [markdown]
# ## ✅ Learning Goals
# - Understand Python data types
# - Use variables and print statements
# - Perform basic arithmetic

# %%
# 🧠 Variables and Types
x = 10
y = 3.5
z = 'hello'
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
# ➕ Arithmetic Operations
print('Add: - 03-Data_Types_and_Arithmetic.ipynb:2', x + y)
print('Divide: - 03-Data_Types_and_Arithmetic.ipynb:3', x / y)
print('Floor Divide: - 03-Data_Types_and_Arithmetic.ipynb:4', x // y)
print('Exponent: - 03-Data_Types_and_Arithmetic.ipynb:5', x ** 2)
# Out:
# Add: - 03-Data_Types_and_Arithmetic.ipynb:4 15
# Divide: - 03-Data_Types_and_Arithmetic.ipynb:5 2.0
# Floor Divide: - 03-Data_Types_and_Arithmetic.ipynb:6 2
# Exponent: - 03-Data_Types_and_Arithmetic.ipynb:7 100

# %% [markdown]
# ## ✏️ Try It Yourself
# - Create your own variables
# - Try combining numbers and strings
# - Use `input()` to interact

# %%
# Your code here
name = input('What is your name? ')
print('Welcome,', name)
# Out:
# Welcome, Jose

# %% [markdown]
# ## 📤 Submit
# Make sure your name is at the top in a Markdown cell.
# Submit via D2L or Colab link.

# %% [markdown]
# ## Jose Marquez
# ## Assignment 03 - Data types and Arithmetic

# %%
# Program to display name, position in lineup (1-6) and score
name = input('Player name: ')
position = input('Position played (1-6): ')
score = input('Score: ')
print(f'{name}, Position: {position}, Score: {score} - 03-Data_Types_and_Arithmetic.ipynb:5')
# Out:
# Jose, Position: 4, Score: 6/4 - 03-Data_Types_and_Arithmetic.ipynb:5
