# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# *Your Answer:*
# %whos displays the variables currently defined in the notebook, along with their types

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# *Your Answer:*
# ## My Hobbies
# - Coding
# - Tennis
# - Gym

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
## Using %pwd to print current working directory
# %pwd
# Out:
# '/Users/josemarioomrqz/4543-5993-Spatial-Maps/Assignments_Completed/Foundations'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open("hello.txt", "w") as f:
    f.write("Hello World")

with open("hello.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Hello World

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.head()
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 11)
y = x**2

plt.plot(x, y)
plt.title("y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# *Your Answer:*
# D,D - pressing D twice in command mode

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np

# %%
# %%timeit
result = []
for x in range(1000):
    result.append(x**2)
# Out:
# 41 μs ± 336 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
arr = np.arange(1000)
# %timeit arr**2
# Out:
# 603 ns ± 5.52 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# *Your Answer:*
# Mixing Markdown and code in Jupyter notebooks is useful because it lets you explain what the code is doing right nex to the code itself. This makes notebooks easier to read, understand, and share with other people. It is especially helpful for assignment, reports and data analysis.
