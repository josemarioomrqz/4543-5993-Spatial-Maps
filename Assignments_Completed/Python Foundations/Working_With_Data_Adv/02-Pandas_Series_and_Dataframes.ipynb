# %% [markdown]
# # 🐼 Notebook 02: Pandas Series and DataFrames
#
# Congratulations. You've graduated from lists and dictionaries — it’s time to wield a more powerful tool: **Pandas**.
#
# This notebook introduces you to the two most essential data structures in data science:
#
# - `Series`: a one-dimensional labeled array (like a dictionary and list had a well-organized child)
# - `DataFrame`: a two-dimensional table with labeled axes (basically Excel’s smarter cousin)
#
# ---

# %%
import pandas as pd

# %% [markdown]
# ## 🔢 Series from a List
# Simple but powerful — labels give it superpowers.

# %%
# A Series from a list — just like a list, but fancier and labeled
prices = pd.Series([2.99, 4.49, 1.99], index=["Apple", "Milk", "Bread"])
print("Grocery Prices:")
print(prices)

# Accessing elements like a dictionary
print("\nPrice of Milk:", prices["Milk"])
# Out:
# Grocery Prices:
# Apple    2.99
# Milk     4.49
# Bread    1.99
# dtype: float64
#
# Price of Milk: 4.49

# %% [markdown]
# ## 🗺️ Series from a Dictionary
# Keys become the index — pretty intuitive, right?

# %%
population = {
    "Texas": 29_000_000,
    "California": 39_000_000,
    "New York": 19_000_000
}

state_pop = pd.Series(population)
print("State Populations:")
print(state_pop)

# Series support math!
print("\nPopulation in millions:")
print(state_pop / 1_000_000)
# Out:
# State Populations:
# Texas         29000000
# California    39000000
# New York      19000000
# dtype: int64
#
# Population in millions:
# Texas         29.0
# California    39.0
# New York      19.0
# dtype: float64

# %% [markdown]
# ## 📋 Creating a DataFrame
# Like a spreadsheet, but you control the universe.

# %%
# Creating a DataFrame — the bread and butter of Pandas
data = {
    "Name": ["Alice", "Bob", "Charlie", "Diana"],
    "GPA": [3.9, 2.7, 3.4, 3.8],
    "Credits": [90, 45, 60, 120],
    "Graduating": [False, False, False, True]
}

students = pd.DataFrame(data)
print("Student DataFrame:")
print(students)
# Out:
# Student DataFrame:
#       Name  GPA  Credits  Graduating
# 0    Alice  3.9       90       False
# 1      Bob  2.7       45       False
# 2  Charlie  3.4       60       False
# 3    Diana  3.8      120        True

# %% [markdown]
# ## 🎯 Column Access + Row Access

# %%
# Access a column
print("\nGPA column:")
print(students["GPA"])

# Access a row
print("\nCharlie's record:")
print(students.loc[2])
# Out:
# GPA column:
# 0    3.9
# 1    2.7
# 2    3.4
# 3    3.8
# Name: GPA, dtype: float64
#
# Charlie's record:
# Name          Charlie
# GPA               3.4
# Credits            60
# Graduating      False
# Name: 2, dtype: object

# %% [markdown]
# ## 🧪 Inspect the DataFrame

# %%
# Shape and structure
print("\nShape:", students.shape)
print("\nColumns:", students.columns.tolist())

# Info dump
print("\nDataFrame Info:")
print(students.info())

# Stats summary
print("\nDataFrame Summary Stats:")
print(students.describe())
# Out:
# Shape: (4, 4)
#
# Columns: ['Name', 'GPA', 'Credits', 'Graduating']
#
# DataFrame Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        4 non-null      str
#  1   GPA         4 non-null      float64
#  2   Credits     4 non-null      int64
#  3   Graduating  4 non-null      bool
# dtypes: bool(1), float64(1), int64(1), str(1)
# memory usage: 232.0 bytes
# None
#
# DataFrame Summary Stats:
#             GPA     Credits
# count  4.000000    4.000000
# mean   3.450000   78.750000
# std    0.544671   33.260337
# min    2.700000   45.000000
# 25%    3.225000   56.250000
# 50%    3.600000   75.000000
# 75%    3.825000   97.500000
# max    3.900000  120.000000

# %% [markdown]
# ## 🧼 Rename a Column

# %%
students.rename(columns={"Graduating": "Is_Graduating"}, inplace=True)
print("\nRenamed column:")
print(students.head())
# Out:
# Renamed column:
#       Name  GPA  Credits  Is_Graduating
# 0    Alice  3.9       90          False
# 1      Bob  2.7       45          False
# 2  Charlie  3.4       60          False
# 3    Diana  3.8      120           True

# %% [markdown]
# ---
# ## 🔍 Your Turn
#
# 1. Create a `Series` from a dictionary of state abbreviations to population (use fake or real data).
# 2. Create a `DataFrame` for 5 students with columns: `Name`, `GPA`, `Credits`, `Graduating` (True/False).
# 3. Try accessing a row using `.loc[]` and a column using bracket notation.
# 4. Print the `.shape`, `.columns`, and `.info()` of your DataFrame.
#
# 🎯 Bonus: Rename a column just to mess with the future grader.

# %%
# Your data science destiny begins here.
# Data from some mexican states population
import pandas as pd
state_population = {
    "Mexico City": 9_200_000,
    "Oaxaca": 4_132_148,
    "San Luis Potosi": 2_822_255,
  
}

state_pop = pd.Series(state_population)
print("Mexican Population: ")
print(state_pop)

print("\nPopulation in millions: ")
print((state_pop / 1_000_000).round(2)) # Round to 2 decimal places for cleaner look
# Out:
# Mexican Population: - 02-Pandas_Series_and_Dataframes.ipynb:12
# Mexico City        9200000
# Oaxaca             4132148
# San Luis Potosi    2822255
# dtype: int64
#
# Population in millions: - 02-Pandas_Series_and_Dataframes.ipynb:15
# Mexico City        9.20
# Oaxaca             4.13
# San Luis Potosi    2.82
# dtype: float64

# %%
# DataFrame of the MSU men's tennis team
import pandas as pd
tennis_data = {
    "Player" : ["Jose Marquez", "Bruno Sanchez", "Geramano Setti", "Juan Duque"],
    "GPA" : [3.0, 3.3, 3.9, 3.8],
    "Credits" : [130, 90, 120, 110],
    "Graduating" : [True, False, True, False]
}

tennis = pd.DataFrame(tennis_data)
print("Student DataFrame: ")
print(tennis)
# Out:
# Student DataFrame:
#            Player  GPA  Credits  Graduating
# 0    Jose Marquez  3.0      130        True
# 1   Bruno Sanchez  3.3       90       False
# 2  Geramano Setti  3.9      120        True
# 3      Juan Duque  3.8      110       False

# %%
# Access a column
print("\nGPA column:")
print(tennis["GPA"])

# Access a row
print("\nGeramano's record: ")
print(tennis.loc[2])
# Out:
# GPA column:
# 0    3.0
# 1    3.3
# 2    3.9
# 3    3.8
# Name: GPA, dtype: float64
#
# Geramano's record:
# Player        Geramano Setti
# GPA                      3.9
# Credits                  120
# Graduating              True
# Name: 2, dtype: object

# %%
print("Shape:")
print(tennis.shape)

print("\nColumns:")
print(tennis.columns)

print("\nInfo:")
tennis.info()

tennis = tennis.rename(columns={"Graduating": "GraduationStatus"})
print("\nUpdated columns:")
print(tennis.columns)
# Out:
# Shape:
# (4, 4)
#
# Columns:
# Index(['Player', 'GPA', 'Credits', 'Graduating'], dtype='str')
#
# Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      4 non-null      str
#  1   GPA         4 non-null      float64
#  2   Credits     4 non-null      int64
#  3   Graduating  4 non-null      bool
# dtypes: bool(1), float64(1), int64(1), str(1)
# memory usage: 232.0 bytes
#
# Updated columns:
# Index(['Player', 'GPA', 'Credits', 'GraduationStatus'], dtype='str')

# %% [markdown]
# ---
# ## 📎 Side Notes
# - A `Series` is like a single column of a spreadsheet.
# - A `DataFrame` is like the full spreadsheet.
# - Rows and columns can both have labels (called the **index** and **columns**).
#
# Next stop: loading data from the real world. Brace yourself for CSVs.
